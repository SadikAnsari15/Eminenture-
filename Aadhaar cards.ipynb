# %% [markdown]
# ## Aadhaar card information

# %% [markdown]
# # dd
# I have extracted information from Aadhaar cards, considering the variations in card formats and text structures. Since Aadhaar cards can differ in layout and content, I have implemented multiple scenarios to handle these variations effectively.
#
# #Store extracted details in a DataFrame
# aadhaar_data = pd.DataFrame([{
#     "Name": name,
#     "DOB": dob,
#     "Gender": gender,
#     "Address": A,
#     "State": state_name,
#     "PIN Code": pin_code
# }])
#
# aadhaar_data.to_excel("Aadhaar_Extracted_Data.xlsx", index=False)
# aadhaar_data
#
# 1 we will this code for save file into excel

# %%
#Store extracted details in a DataFrame
aadhaar_data = pd.DataFrame([{
    "Name": name,
    "DOB": dob,
    "Gender": gender,
    "Address": A,
    "State": state_name,
    "PIN Code": pin_code
}])

# Save DataFrame to an Excel file
aadhaar_data.to_excel("Aadhaar_Extracted_Data.xlsx", index=False)

# Display DataFrame
aadhaar_data
1 we will this code for save file into excel

# %%
import os
import pandas as pd

# Load the Aadhaar card image
image_path = "C:/Users/HP/Downloads/QA - Supporting Files/QA - Supporting Files/QA - 5 - Aadhar Cards/a7.jpg"

if os.path.exists(image_path):
    print("✅ Image file found!")
else:
    print("❌ Error: Image file not found.")
# Out:
# ✅ Image file found!

# %%
# a7
import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = r"C:\Users\HP\Downloads\QA - Supporting Files\QA - Supporting Files\QA - 5 - Aadhar Cards\a7.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    name = lines[3].strip()
else:
    name = "Not Found"
    
if len(lines) >= 5:
    DOB = lines[4].strip()
else:
    DOB = "Not Found"

# Use regex to find DOB in the correct format
dob_match = re.search(r'DOB:\s*\d{2}/\d{2}/\d{4}', DOB)

# Get the correct DOB format or return "Not Found"
dob = dob_match.group(0) if dob_match else "Not Found"
    
if len(lines) >= 6:
    G = lines[6].strip()
else:
    G = "Not Found" 
# Use regex to extract gender after "/"
gender_match = re.search(r'\/\s*(Male|Female|Other)', G, re.IGNORECASE)

# Get the gender or return "Not Found"
gender = gender_match.group(1) if gender_match else "Not Found"    


if len(lines) >= 10:
    A = lines[10].strip()
else:
    A = "Not Found"

if len(lines) >= 11:
    D = lines[11].strip()
else:
    D = "Not Found"
    
# Remove 6-digit PIN code
state_name = re.sub(r'\b\d{6}\b', '', D).strip()
# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()

# Output the result
print(f"Name: {name}")
print(f"{dob}")
print(f"Gender {gender}")
print(f"Address {A}")
print(f"State {state_name}")
print(f"PIN Code {pin_code}")



#Store extracted details in a DataFrame
aadhaar_data = pd.DataFrame([{
    "Name": name,
    "DOB": dob,
    "Gender": gender,
    "Address": A,
    "State": state_name,
    "PIN Code": pin_code
}])

# Save DataFrame to an Excel file
aadhaar_data.to_excel("Aadhaar_Extracted_Data.xlsx", index=False)

# Display DataFrame
aadhaar_data
# Out:
# Name: Vasava Dipakbhai
# DOB: 25/08/1995
# Gender Male
# Address AT.VASKA PO. PIPDI TA. VAGALI DIST.
# State NARMDA
# PIN Code 392330
# C:\Users\HP\AppData\Local\Temp\ipykernel_36792\1379008918.py:88: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   aadhaar_data.to_excel("Aadhaar_Extracted_Data.xlsx", index=False)
#                Name              DOB Gender  \
# 0  Vasava Dipakbhai  DOB: 25/08/1995   Male
#
#                                Address   State PIN Code
# 0  AT.VASKA PO. PIPDI TA. VAGALI DIST.  NARMDA   392330

# %%
# a2 

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = r"C:\Users\HP\Downloads\QA - Supporting Files\QA - Supporting Files\QA - 5 - Aadhar Cards\a2.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 5:
    fourth_row = lines[1].strip()
else:
    fourth_row = "Not Found"
    
if len(lines) >= 10:
    AD = lines[3].strip()
else:
    AD = "Not Found"

    
if len(lines) >= 5:
    DOB = lines[2].strip()
else:
    DOB = "Not Found"

# Use regex to find DOB in the correct format
dob_match = re.search(r'DOB:\s*\d{2}/\d{2}/\d{4}', DOB)

# Get the correct DOB format or return "Not Found"
dob = dob_match.group(0) if dob_match else "Not Found"
    
if len(lines) >= 6:
    G = lines[6].strip()
else:
    G = "Not Found" 
# Use regex to extract gender after "/"
gender_match = re.search(r'\/\s*(Male|Female|Other)', G, re.IGNORECASE)

# Get the gender or return "Not Found"
gender = gender_match.group(1) if gender_match else "Not Found"    


if len(lines) >= 10:
    A = lines[8].strip()
else:
    A = "Not Found"

last_word = A.split(",")[-1].strip()
# Remove the last word
new_text = ", ".join(A.split(",")[:-1]).strip()
    
if len(lines) >= 11:
    D = lines[11].strip()
else:
    D = "Not Found"
    



# Output the result
print(f"Name: {fourth_row}")
print(f"DOB {dob}")
print(f"Adhar no.  {AD}")
print(f"Gender {gender}")
print(f"Address {new_text}")
print(f"State {last_word}")
print(f"PIN Code {pin_code}")


# Store extracted details in a DataFrame
aadhaar_data = pd.DataFrame([{
    "Name": fourth_row,
    "DOB": dob,
    "Aadhaar Number": AD,
    "Gender": gender,
    "Address": new_text,
    "State": last_word,
    "PIN Code": pin_code
}])

# Save DataFrame to an Excel file
aadhaar_data.to_excel("Aadhaar_Extracted_Data_A2.xlsx", index=False)

# Display DataFrame
aadhaar_data
# Out:
# Name: John Ikhlaaq
# DOB Not Found
# Adhar no.  7150 9454 5128
# Gender Not Found
# Address Anjaan Desh
# State Mamta
# PIN Code 392330
# C:\Users\HP\AppData\Local\Temp\ipykernel_36792\2100136927.py:92: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   aadhaar_data.to_excel("Aadhaar_Extracted_Data_A2.xlsx", index=False)
#            Name        DOB  Aadhaar Number     Gender      Address  State  \
# 0  John Ikhlaaq  Not Found  7150 9454 5128  Not Found  Anjaan Desh  Mamta
#
#   PIN Code
# 0   392330

# %%
# a5 

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = r"C:\Users\HP\Downloads\QA - Supporting Files\QA - Supporting Files\QA - 5 - Aadhar Cards\a5.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    fourth_row = lines[4].strip()
else:
    fourth_row = "Not Found"
    
if len(lines) >= 6:
    DOB = lines[6].strip()
else:
    DOB = "Not Found"

# Use regex to find DOB in the correct format
dob_match = re.search(r'DOB:\s*\d{2}/\d{2}/\d{4}', DOB)

# Get the correct DOB format or return "Not Found"
dob = dob_match.group(0) if dob_match else "Not Found"
    
if len(lines) >= 6:
    G = lines[5].strip()
else:
    G = "Not Found" 
# Use regex to extract gender after "/"
gender_match = re.search(r'\/\s*(Male|Female|Other)', G, re.IGNORECASE)

# Get the gender or return "Not Found"
gender = gender_match.group(1) if gender_match else "Not Found"    


if len(lines) >= 11:
    A = lines[11].strip()
else:
    A = "Not Found"

if len(lines) >= 15:
    D = lines[15].strip()
else:
    D = "Not Found"
    
if len(lines) >= 14:
    extracted_lines = "\n".join(lines[10:14])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "Not Found"
# Remove unwanted words
cleaned_text = re.sub(r"(; \+ S/O:|Se: = MGT, 207, TSE FOR,|AT, 1 4-6, THAT ATT, =)", "", extracted_lines)

# Strip extra spaces
cleaned_text = cleaned_text.strip()
    
# Remove 6-digit PIN code
state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()

# Extract Aadhaar Number (Format: XXXX XXXX XXXX)
aadhaar_number = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_number[0] if aadhaar_number else "Not Found"

# Output the result
print(f"Name: {fourth_row}")
print(f"DOB {dob}")
print(f"Gender {gender}")
print("Aadhaar Number:", aadhaar_number)
print(f"Address {cleaned_text}")
print(f"State {state_name}")
print(f"PIN Code {pin_code}")


# Store extracted details in a DataFrame
aadhaar_data = pd.DataFrame([{
    "Name": fourth_row,
    "DOB": dob,
    "Aadhaar Number": aadhaar_number,
    "Gender": gender,
    "Address": cleaned_text,
    "State": state_name,
    "PIN Code": pin_code
}])

# Save DataFrame to an Excel file
aadhaar_data.to_excel("Aadhaar_Extracted_Data_A5.xlsx", index=False)

# Display DataFrame
aadhaar_data
# Out:
# Name: Ajmal Khan
# DOB DOB: 12/07/1979
# Gender Not Found
# Aadhaar Number: 7715 3568 3287
# Address Imtiyaz Kha, 207, GROUND
#  LANE NO-6, GAFFAR
#  MANZIL, JAMIA NAGAR, Okhla,
# State fet : Delhi -
# PIN Code 110025
# C:\Users\HP\AppData\Local\Temp\ipykernel_36792\4272143439.py:106: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   aadhaar_data.to_excel("Aadhaar_Extracted_Data_A5.xlsx", index=False)
#          Name              DOB  Aadhaar Number     Gender  \
# 0  Ajmal Khan  DOB: 12/07/1979  7715 3568 3287  Not Found
#
#                                              Address          State PIN Code
# 0  Imtiyaz Kha, 207, GROUND\n LANE NO-6, GAFFAR\n...  fet : Delhi -   110025

# %%
# a6

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = r"C:\Users\HP\Downloads\QA - Supporting Files\QA - Supporting Files\QA - 5 - Aadhar Cards\a6.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    Name = lines[1].strip()
else:
    Name = "Not Found"
     

if len(lines) >= 11:
    A = lines[11].strip()
else:
    A = "Not Found"
    
# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", A)
state = state_match.group(0) if state_match else "State Not Found"

if len(lines) >= 14:
    extracted_lines = "\n".join(lines[7:8])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "Not Found"


# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", extracted_lines)
state = state_match.group(0) if state_match else "State Not Found"
    
# Remove 6-digit PIN code
state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()

# Extract Aadhaar Number (Format: XXXX XXXX XXXX)
aadhaar_number = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\b', extracted_lines)
aadhaar_number = aadhaar_number[0] if aadhaar_number else "Not Found"



#..........................


# Join all lines into a single string
text = "\n".join(lines)

# Extract DOB
dob_match = re.search(r"DOB:\s*(\d{1,2}/\d{1,2}/\d{4})", text)
dob = dob_match.group(0) if dob_match else "DOB Not Found"

# Extract Gender (Male/Female)
gender_match = re.search(r"\bMale\b|\bFemale\b", text)
gender = gender_match.group(0) if gender_match else "Gender Not Found"


# Extract Text using OCR
#extracted_text = pytesseract.image_to_string(thresh, lang="eng")
# Extract Aadhaar Number (Format: XXXX XXXX XXXX)
aadhaar_number = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_number[0] if aadhaar_number else "Not Found"


# Output the result
print(f"Name: {Name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print("Aadhaar Number:", aadhaar_number)
print(f"Address: {cleaned_text}")
print(f"State: {state}")
print(f"PIN Code: {pin_code}")
# Out:
# Name: Anmol Razz
# DOB: DOB: 5/2/1999
# Gender: Male
# Aadhaar Number: Not Found
# Address: Imtiyaz Kha, 207, GROUND
#  LANE NO-6, GAFFAR
#  MANZIL, JAMIA NAGAR, Okhla,
# State: bihar
# PIN Code: 110025

# %%
# a1

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = "C:/Users/HP/Downloads/QA - Supporting Files/QA - Supporting Files/QA - 5 - Aadhar Cards/a1.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    Name = lines[4].strip()
else:
    Name = "Not Found"
     

if len(lines) >= 15:
    A = lines[10].strip()
else:
    A = "Not Found"
    

if len(lines) >= 14:
    extracted_lines = "\n".join(lines[7:8])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "NotFound"


# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", extracted_lines)
s = state_match.group(0) if state_match else "Not Found"
    
# Remove 6-digit PIN code
#state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()


# Join all lines into a single string
text = "\n".join(lines)

# Extract DOB
dob_match = re.search(r"DOB:\s*(\d{1,2}/\d{1,2}/\d{4})", text)
dob = dob_match.group(0) if dob_match else "DOB Not Found"

# Extract Gender (Male/Female)
gender_match = re.search(r"\bMale\b|\bFemale\b", text)
gender = gender_match.group(0) if gender_match else "Gender Not "


# Extract Text using OCR
extracted_text = pytesseract.image_to_string(thresh, lang="eng")
# Extract Aadhaar Number (16-digit with spaces: XXXX XXXX XXXX XXXX)
aadhaar_numbers = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_numbers[0] if aadhaar_numbers else "Not Found"


# Output the result
print(f"Name: {Name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print("Aadhaar Number:", aadhaar_number)
print(f"Address: {A}")
print(f"State : {s}")
print(f"PIN Code: {pin_code}")
# Out:
# Name: Pradeep Verma
# DOB: DOB: 01/02/1996
# Gender: Male
# Aadhaar Number: 5686 5772 6886 1788
# Address: Not Found
# State : NotFound
# PIN Code: Not Found

# %%
# a4 

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = "C:/Users/HP/Downloads/QA - Supporting Files/QA - Supporting Files/QA - 5 - Aadhar Cards/a4.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    Name = lines[1].strip()
else:
    Name = "Not Found"
     

if len(lines) >= 15:
    A = lines[10].strip()
else:
    A = "Not Found"
    

if len(lines) >= 14:
    extracted_lines = "\n".join(lines[7:8])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "NotFound"


# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", extracted_lines)
s = state_match.group(0) if state_match else "Not Found"
    
# Remove 6-digit PIN code
#state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()


# Join all lines into a single string
text = "\n".join(lines)

# Extract DOB
dob_match = re.search(r"DOB:\s*(\d{1,2}/\d{1,2}/\d{4})", text)
dob = dob_match.group(0) if dob_match else "DOB Not Found"

# Extract Gender (Male/Female)
gender_match = re.search(r"\bMale\b|\bFemale\b", text)
gender = gender_match.group(0) if gender_match else "Gender Not "


# Extract Text using OCR
extracted_text = pytesseract.image_to_string(thresh, lang="eng")

# Extract Aadhaar Number (16-digit with spaces: XXXX XXXX XXXX XXXX)
aadhaar_numbers = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_numbers[0] if aadhaar_numbers else "Not Found"

# Output the result
print(f"Name: {Name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print("Aadhaar Number:", aadhaar_number)
print(f"Address: {A}")
print(f"State : {s}")
print(f"PIN Code: {pin_code}")
# Out:
# Name: Bhuvan Bam
# DOB: DOB:21/1/1994
# Gender: Male
# Aadhaar Number: 5686 5772 6886 1788
# Address: Not Found
# State : NotFound
# PIN Code: Not Found

# %%
# a8 


import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = "C:/Users/HP/Downloads/QA - Supporting Files/QA - Supporting Files/QA - 5 - Aadhar Cards/a8.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 10:
    Name = lines[3].strip()
else:
    Name = "Not Found"
    
if len(lines) >= 15:
    A = lines[10].strip()
else:
    A = "Not Found"

if len(lines) >= 25:
    Adharok = lines[10:12]  # Extracts lines from index 10 to 25 (Python indexing is 0-based)
else:
    Adharok = lines[10:15]
# Join the selected lines into a single string (optional)
Adharok = "\n".join(selected_lines)

if len(lines) >= 14:
    extracted_lines = "\n".join(lines[7:8])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "NotFound"


# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", extracted_lines)
s = state_match.group(0) if state_match else "Not Found"
    
# Remove 6-digit PIN code
#state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()


# Join all lines into a single string
text = "\n".join(lines)

# Extract DOB
dob_match = re.search(r"DOB:\s*(\d{1,2}/\d{1,2}/\d{4})", text)
dob = dob_match.group(0) if dob_match else "DOB Not Found"

# Extract Gender (Male/Female)
gender_match = re.search(r"\bMale\b|\bFemale\b", text)
gender = gender_match.group(0) if gender_match else "Gender Not "


# Extract Text using OCR
extracted_text = pytesseract.image_to_string(thresh, lang="eng")

# Extract Aadhaar Number (16-digit with spaces: XXXX XXXX XXXX XXXX)
aadhaar_numbers = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_numbers[0] if aadhaar_numbers else "Not Found"

# Output the result
print(f"Name: {Name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print("Aadhaar Number:", Adharok)
print(f"Address: {A}")
print(f"State : {s}")
print(f"PIN Code: {pin_code}")
# Out:
# Name: Anoop Negi
# DOB: DOB: 30/06/1997
# Gender: Male
# Aadhaar Number: 2135 7856 8745
# Address: Not Found
# State : NotFound
# PIN Code: Not Found

# %%
#a9 

import pytesseract
from PIL import Image

# Set up Tesseract path (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the image
image_path = r"C:\Users\HP\Downloads\QA - Supporting Files\QA - Supporting Files\QA - 5 - Aadhar Cards\a9.jpg"
image = Image.open(image_path)

# Extract text from the image
extracted_text = pytesseract.image_to_string(image)

# Split the text into lines
lines = extracted_text.split("\n")

# Get the 4th row (index 3 since indexing starts from 0)
if len(lines) >= 4:
    fourth_row = lines[2].strip()
else:
    fourth_row = "Not Found"
    

# Extract Date of Birth (Format: DD/MM/YYYY or DD-MM-YYYY)
# Extract Text using OCR
extracted_text = pytesseract.image_to_string(thresh, lang="eng")
dob = re.findall(r'\b\d{2}[-/]\d{2}[-/]\d{4}\b', extracted_text)
dob = dob[0] if dob else "Not Found"


    
if len(lines) >= 6:
    G = lines[5].strip()
else:
    G = "Not Found" 
  
    
if len(lines) >= 14:
    extracted_lines = "\n".join(lines[10:14])  # Extracting lines 11 to 14 (Indexing starts from 0)
else:
    extracted_lines = "Not Found"

    
# Remove 6-digit PIN code
state_name = re.sub(r'\b\d{6}\b', '', D).strip()


# Use regex to extract the 6-digit PIN code
pin_code_match = re.search(r'\b\d{6}\b', D)

# Get the PIN code or return "Not Found"
pin_code = pin_code_match.group(0) if pin_code_match else "Not Found"


lines[0] = re.sub(r'\b\d{6}\b', '', lines[0]).strip()

# Extract Aadhaar Number (Format: XXXX XXXX XXXX)
aadhaar_number = re.findall(r'\b\d{4}\s\d{4}\s\d{4}\b', extracted_text)
aadhaar_number = aadhaar_number[0] if aadhaar_number else "Not Found"

address = " ".join(lines[14:20])
state1 = " ".join(lines[20:21])

# Extract PIN Code (6-digit number)
pin_code = re.findall(r'\b\d{6}\b', extracted_text)
pin_code = pin_code[0] if pin_code else "Not Found"



# Output the result
print(f"Name: {fourth_row}")
print(f"DOB: {dob}")
print(f"Gender: {G}")
print("Aadhaar Number:", aadhaar_number)
print(f"Address: {address}")
print(f"State: {state1}")
print(f"PIN Code {pin_code}")
# Out:
# Name: surishta Devi
# DOB: 03-12-1981
# Gender: Female
# Aadhaar Number: 6781 5338 1876
# Address: w/o Devendra Singh  00.00 jhandi chaur  pachhimi pauri
# State: garhwal Uttarakhand
# PIN Code 246149

# %%
#a10 
import pytesseract
from PIL import Image

# Load the image
image_path = "a10.png"
image = Image.open(image_path)

# Extract text using pytesseract
extracted_text = pytesseract.image_to_string(image, lang="eng")

# Display extracted text
extracted_text

import re
data = extracted_text


# Split the data into lines
lines = data.split("\n")


# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", data)
s = state_match.group(0) if state_match else "Not Found"
# Extract details
name = lines[2].strip().replace('"', '')  # Remove any quotes
dob_match = re.search(r'\d{4}', data)  # Extract year of birth
dob = dob_match.group(0) if dob_match else "N/A"
gender_match = re.search(r'\bMale\b|\bFemale\b', data)  # Extract gender
gender = gender_match.group(0) if gender_match else "N/A"
aadhaar_match = re.search(r'\d{4} \d{4} \d{4}', data)  # Extract Aadhaar number
aadhaar_number = aadhaar_match.group(0) if aadhaar_match else "N/A"

# Extract address by finding the relevant lines
address_start = data.find("S/O:")
address_end = data.rfind("Meerut") + len("250002")
address = data[address_start:address_end].replace("\n", " ").strip()



# Print extracted information
print("\nExtracted Aadhaar Card Information:")
print(f"Name: {name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print(f"Aadhaar Number: {aadhaar_number}")
print(f"Address: {address}")
print(f"State: {state}")
print(f"PIN Code: {pin_code}")
print(f"State: {s}")
# Out:
# Extracted Aadhaar Card Information:
# Name: Rajeev Sharma
# DOB: 1982
# Gender: Male
# Aadhaar Number: 6903 2611 1844
# Address: S/O: Nepal Singh, # 418 gali no  sige. 1, Post office -kishan pura, mest ~ police check post new mutan  freer Fr, ee es ——_ agar, bhola road meerut  Meerut, Navinmandi, Meerut
# State: Uttar Pradesh
# PIN Code: 250002
# State: Not Found

# %%
#a3
import pytesseract
from PIL import Image

# Load the image
image_path = "a3.jpeg"
image = Image.open(image_path)

# Extract text using pytesseract
extracted_text = pytesseract.image_to_string(image, lang="eng")

# Display extracted text
extracted_text

import re
data = extracted_text


# Split the data into lines
lines = data.split("\n")

# Extract State (Assume it's the last word in the address)
state_match = re.search(r"\b\w+$", data)
state = state_match.group(0) if state_match else "Not Found"
# Extract details
name = lines[1].strip().replace('"', '')  # Remove any quotes
dob_match = re.search(r'\d{4}', data)  # Extract year of birth
dob = dob_match.group(0) if dob_match else "N/A"
gender_match = re.search(r'\bMale\b|\bFemale\b', data)  # Extract gender
gender = gender_match.group(0) if gender_match else "N/A"
aadhaar_match = re.search(r'\b\d{4}\s\d{4}\s\d{4}(\s\d{4})?\b', data)  
aadhaar_number = aadhaar_match.group(0) if aadhaar_match else "N/A"




# Extract state and PIN code

pin_code_match = re.search(r'\b\d{6}\b', data)  # Extract PIN code
pin_code = pin_code_match.group(0) if pin_code_match else "N/A"

# Print extracted information
print("\nExtracted Aadhaar Card Information:")
print(f"Name: {name}")
print(f"DOB: {dob}")
print(f"Gender: {gender}")
print(f"Aadhaar Number: {aadhaar_number}")
print(f"Address: {address}")
print(f"State: {state}")
print(f"PIN Code: {pin_code}")
# Out:
# Extracted Aadhaar Card Information:
# Name: Harsh Yadav
# DOB: 1984
# Gender: Male
# Aadhaar Number: 8108 6494 9408 6584
# Address:
# State: Not Found
# PIN Code: N/A
